# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('/content/Bank Rate history and data  Bank of England Database.xlsx')
df
# Out:
#     Bank Rate history and data | Bank of England Database Unnamed: 1
# 0                                         Date Changed          Rate
# 1                                            06 Feb 25           4.5
# 2                                            07 Nov 24          4.75
# 3                                            01 Aug 24             5
# 4                                            03 Aug 23          5.25
# ..                                                 ...           ...
# 251                                          10 Mar 75         10.25
# 252                                          17 Feb 75          10.5
# 253                                          10 Feb 75         10.75
# 254                                          27 Jan 75            11
# 255                                          20 Jan 75         11.25
#
# [256 rows x 2 columns]

# %%
df.rename(columns={'Bank Rate history and data | Bank of England Database': 'Date'}, inplace=True)
df.rename(columns={'Unnamed: 1': 'Rate'}, inplace=True)
df.drop(0,inplace=True)
df
# Out:
#           Date   Rate
# 1    06 Feb 25    4.5
# 2    07 Nov 24   4.75
# 3    01 Aug 24      5
# 4    03 Aug 23   5.25
# 5    22 Jun 23      5
# ..         ...    ...
# 251  10 Mar 75  10.25
# 252  17 Feb 75   10.5
# 253  10 Feb 75  10.75
# 254  27 Jan 75     11
# 255  20 Jan 75  11.25
#
# [255 rows x 2 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
# <ipython-input-181-e0d9d975d684>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])
#           Date   Rate
# 1   2025-02-06    4.5
# 2   2024-11-07   4.75
# 3   2024-08-01      5
# 4   2023-08-03   5.25
# 5   2023-06-22      5
# ..         ...    ...
# 251 1975-03-10  10.25
# 252 1975-02-17   10.5
# 253 1975-02-10  10.75
# 254 1975-01-27     11
# 255 1975-01-20  11.25
#
# [255 rows x 2 columns]

# %%
df1=pd.read_excel('/content/FTSE 100 Historical Data (2).xlsx')
df1.rename(columns={'ï»¿"Date"': 'Date'}, inplace=True)
df1
df1['Date'] = pd.to_datetime(df1['Date'])

# Extract only the year
df1['Year'] = df1['Date'].dt.year

# Drop the original 'date' column if no longer needed
df1.drop(columns=['Date'], inplace=True)

# Display the DataFrame
df1.drop(columns=['Vol.'], inplace=True)

# %%
df1_year = df1.groupby('Year')
print(df1_year)

# %%
Mean_1=df1_year.mean()
Mean_1
# Out:
#             Price         Open         High          Low  Change %
# Year
# 2001  5472.300000  5570.490909  5741.390909  5205.818182 -0.016118
# 2002  4565.791667  4672.208333  4804.491667  4358.475000 -0.021550
# 2003  4029.835833  3985.133333  4173.091667  3872.150000  0.011575
# 2004  4519.822500  4491.716667  4613.041667  4422.041667  0.006225
# 2005  5167.510833  5100.483333  5254.700000  5037.475000  0.013217
# 2006  5940.907500  5890.725000  6048.391667  5758.591667  0.008767
# 2007  6425.190000  6405.516667  6570.283333  6187.491667  0.003417
# 2008  5356.945833  5525.512500  5681.557500  5002.611667 -0.029025
# 2009  4593.000000  4511.440833  4771.403333  4335.361667  0.018133
# 2010  5418.041667  5377.453333  5639.010833  5212.090000  0.008358
# 2011  5727.619167  5754.924167  5906.788333  5443.799167 -0.004067
# 2012  5715.626667  5688.499167  5873.054167  5581.869167  0.005142
# 2013  6492.117500  6421.177500  6637.310833  6284.056667  0.011892
# ...

# %%
Max_1=df1_year.max()
Max_1
# Out:
#         Price     Open     High      Low  Change %
# 2012     157.587812  151.267310  111.587821  185.156067  0.029614
# 2013     173.437474  225.159109  163.726623  192.791238  0.035395
# ...

# %%
Mean_1=df1_year.mean()
Mean_1.rename(columns={'Price': 'Price_FTSE100'}, inplace=True)
Mean_1
# Out:
#       Price_FTSE100         Open         High          Low  Change %
# Year
# 2001    5472.300000  5570.490909  5741.390909  5205.818182 -0.016118
# 2002    4565.791667  4672.208333  4804.491667  4358.475000 -0.021550
# 2003    4029.835833  3985.133333  4173.091667  3872.150000  0.011575
# 2004    4519.822500  4491.716667  4613.041667  4422.041667  0.006225
# 2005    5167.510833  5100.483333  5254.700000  5037.475000  0.013217
# 2006    5940.907500  5890.725000  6048.391667  5758.591667  0.008767
# 2007    6425.190000  6405.516667  6570.283333  6187.491667  0.003417
# 2008    5356.945833  5525.512500  5681.557500  5002.611667 -0.029025
# 2009    4593.000000  4511.440833  4771.403333  4335.361667  0.018133
# 2010    5418.041667  5377.453333  5639.010833  5212.090000  0.008358
# 2011    5727.619167  5754.924167  5906.788333  5443.799167 -0.004067
# 2012    5715.626667  5688.499167  5873.054167  5581.869167  0.005142
# ...

# %%
Standard_Deviation_Price_FTSE100 = Standard_Deviation_1['Price_FTSE100']
Standard_Deviation_Price_FTSE100
# Out:
# Year
# 2001    356.433466
# 2002    566.923008
# 2003    292.292901
# 2004    133.580729
# 2005    271.250120
# 2006    150.203959
# 2007    167.774122
# 2008    674.407589
# 2009    532.580906
# 2010    275.954461
# 2011    292.383435
# 2012    157.587812
# 2013    173.437474
# 2014    116.706766
# 2015    318.609101
# 2016    373.875910
# 2017    154.290632
# 2018    318.123799
# 2019    184.763694
# 2020    465.978521
# 2021    288.715006
# 2022    218.630985
# 2023    180.402839
# 2024    253.259822
# 2025     39.421203
# Name: Price_FTSE100, dtype: float64

# %%
Mean_Price_FTSE100 = Mean_1['Price_FTSE100']
Mean_Price_FTSE100
# Out:
# Year
# 2001    5472.300000
# 2002    4565.791667
# 2003    4029.835833
# 2004    4519.822500
# 2005    5167.510833
# 2006    5940.907500
# 2007    6425.190000
# 2008    5356.945833
# 2009    4593.000000
# 2010    5418.041667
# 2011    5727.619167
# 2012    5715.626667
# 2013    6492.117500
# 2014    6691.229167
# 2015    6575.039167
# 2016    6551.575000
# 2017    7367.085000
# 2018    7347.862500
# 2019    7305.654167
# 2020    6143.128333
# 2021    6962.865833
# 2022    7373.375000
# 2023    7615.274167
# 2024    8112.401667
# 2025    8701.835000
# Name: Price_FTSE100, dtype: float64

# %%
df2=pd.read_excel('/content/Gold Futures Historical Data (1).xlsx')
df2.rename(columns={'ï»¿"Date"': 'Date'}, inplace=True)
df2
df2['Date'] = pd.to_datetime(df2['Date'])

# Extract only the year
df2['Year'] = df2['Date'].dt.year

# Drop the original 'date' column if no longer needed
df2.drop(columns=['Date'], inplace=True)

# Display the DataFrame
df2.drop(columns=['Vol.'], inplace=True)
df2
# Out:
#       Price    Open    High     Low  Change %  Year
# 0    2883.6  2818.2  2945.4  2780.9    0.0253  2025
Mean_Price_Gold
# Out:
# Year
# 2000     277.050000
# 2001     271.275000
# 2002     312.770833
# 2003     368.008333
# 2004     411.408333
# 2005     448.641667
# 2006     613.908333
# 2007     705.483333
# 2008     876.775000
# 2009     984.783333
# 2010    1237.783333
# 2011    1574.075000
# 2012    1676.325000
# 2013    1394.400000
# 2014    1251.308333
# 2015    1152.258333
# 2016    1247.366667
# 2017    1266.508333
# 2018    1264.266667
# 2019    1402.600000
# 2020    1775.716667
# 2021    1791.400000
# 2022    1794.950000
# 2023    1953.750000
# 2024    2402.866667
# 2025    2848.050000
# Name: Price_Gold, dtype: float64

# %%
Standard_Deviation_Price_Gold = Standard_Deviation_2['Price_Gold']
Standard_Deviation_Price_Gold
# Out:
# Year
# 2000      8.117042
# 2001      9.203075
# 2002     16.283629
# 2003     24.520546
# 2004     20.998028
# 2005     31.211258
# 2006     30.610083
# 2007     64.609820
# 2008     66.363929
# 2009     83.995128
# 2010    110.964432
# 2011    145.196357
# 2012     60.027692
# 2013    151.917011
# 2014     55.231734
# 2015     63.462651
# 2016     73.552224
# 2017     28.499743
# 2018     53.646170
# 2019     94.532082
# 2020    146.956882
# 2021     52.658471
# 2022     97.137892
# 2023     67.750646
# 2024    234.255743
# 2025     50.275292
# Name: Price_Gold, dtype: float64

# %%
df3=pd.read_excel('/content/Natural Gas Futures Historical Data (1).xlsx')
df3.rename(columns={'ï»¿"Date"': 'Date'}, inplace=True)
df3
df3['Date'] = pd.to_datetime(df3['Date'])

# Extract only the year
df3['Year'] = df3['Date'].dt.year

# Drop the original 'date' column if no longer needed
df3.drop(columns=['Date'], inplace=True)
df3.drop(columns=['Vol.'], inplace=True)

# Display the DataFrame
df3
# Out:
#      Price   Open   High    Low  Change %  Year
# 0    3.725  3.230  3.801  3.161    0.2237  2025
# 1    3.044  3.656  4.369  2.990   -0.1621  2025
# 2    3.633  3.220  4.201  2.977    0.0803  2024
# 3    3.363  2.702  3.563  2.514    0.2423  2024
# 4    2.707  2.907  3.019  2.200   -0.0739  2024
# ..     ...    ...    ...    ...       ...   ...
# 297  4.356  3.175  4.555  3.010    0.3868  2000
# 298  3.141  2.940  3.175  2.815    0.0666  2000
# 299  2.945  2.760  2.980  2.670    0.0666  2000
# 300  2.761  2.670  2.780  2.465    0.0372  2000
# 301  2.662  2.130  2.680  2.125    0.1430  2000
#
# [302 rows x 6 columns]

# %%
df3_year = df3.groupby('Year')
print(df3_year)

# %%
Mean_3=df3_year.mean()
Mean_3
# Out:
#          Price      Open       High       Low  Change %
# Year
# 2000  4.578083  3.939833   4.849917  3.700583  0.144942
# 2001  3.679583  4.230500   4.766583  3.376750 -0.084300
# 2002  3.464000  3.267833   3.779500  2.964333  0.064692
# 2003  5.508250  5.402500   6.624000  4.832917  0.041883
# 2004  6.306667  6.323083   7.066667  5.609583  0.011675
# 2005  9.162000  8.705083  10.201583  8.021500  0.062583
# 2006  7.069917  7.421667   8.322250  6.049833 -0.024883
# 2007  7.242667  7.123917   7.835667  6.502917  0.022983
# 2011    4.076833
# 2012    2.892333
# 2013    3.757750
# 2014    4.218167
# 2015    2.592667
# 2016    2.677417
# 2017    3.014833
# 2018    3.046083
# 2019    2.464667
# 2020    2.203750
# 2021    3.782583
# 2022    6.467750
# 2023    2.695250
# 2024    2.486333
# 2025    3.384500
# Name: Price_Gas, dtype: float64

# %%
df4=pd.read_excel('/content/Silver Futures Historical Data (1).xlsx')
df4.rename(columns={'ï»¿"Date"': 'Date'}, inplace=True)
df4
df4['Date'] = pd.to_datetime(df4['Date'])

# Extract only the year
df4['Year'] = df4['Date'].dt.year

# Drop the original 'date' column if no longer needed
df4.drop(columns=['Date'], inplace=True)
df4.drop(columns=['Vol.'], inplace=True)

# Display the DataFrame
df4
# Out:
#      Price   Open   High    Low  Change %  Year
# 0    33.35  32.87  34.51  32.17    0.0153  2025
# 1    32.85  30.00  33.50  30.00    0.1001  2025
# 2    29.86  31.38  33.51  29.41   -0.0481  2024
# 3    31.37  33.52  33.95  30.40   -0.0641  2024
# 4    33.52  31.81  35.53  30.75    0.0526  2024
# ..     ...    ...    ...    ...       ...   ...
# 297   5.06   5.12   5.27   5.03   -0.0078  2000
# 298   5.10   5.16   5.26   5.04   -0.0039  2000
# 299   5.12   5.25   5.28   5.05   -0.0097  2000
# 300   5.17   5.36   5.63   5.11   -0.0372  2000
# 301   5.37   5.34   5.45   5.16   -0.0183  2000
#
# [302 rows x 6 columns]

# %%
df4_year = df4.groupby('Year')
print(df4_year)

# %%
Mean_4=df4_year.mean()
Mean_4
# Out:
#           Price       Open       High        Low  Change %
# Year
# 2000   5.050000   5.088333   5.189167   4.965833 -0.012125
# 2001   4.452500   4.458333   4.610000   4.326667 -0.000650
# 2002   4.629167   4.632500   4.791667   4.469167  0.005900
# 2003   4.975000   4.873333   5.110833   4.730833  0.019183
# 2004   6.795000   6.820833   7.210000   6.294167  0.017758
# 2005   7.519167   7.318333   7.783333   7.104167  0.024358
# 2006  12.106667  11.880000  12.808333  10.971667  0.037717
# 2007  13.846667  13.707500  14.377500  12.995000  0.013675
# 2008  15.142500  15.398333  16.622500  13.734167 -0.015733
# 2009  14.815000  14.376667  15.748333  13.613333  0.039242
# 2010  20.810000  19.664167  21.447500  19.015833  0.053825
# 2011  35.752500  35.721667  39.361667  31.204167  0.005958
# 2012  31.469167  31.305000  33.381667  29.539167  0.010383
# 2013  23.422500  24.475000  25.483333  22.175000 -0.032583
# 2014  18.665833  18.994167  19.975000  18.089167 -0.015633
# ...

# %%
Max_4=df4_year.max()
Max_4
# Out:
#       Price   Open   High    Low  Change %
# Year
# 2000   5.37   5.36   5.63   5.16    0.0217
# 2001   4.92   4.88   4.96   4.61    0.1137
# 2002   5.09   5.08   5.20   4.83    0.1065
# 2003   5.99   5.42   6.06   5.42    0.1176
# 2004   7.96   8.12   8.30   7.01    0.1810
# 2005   9.03   8.50   9.36   8.35    0.1019
# 2006  14.24  14.23  15.20  12.63    0.1804
# 2007  15.15  14.87  16.39  14.10    0.1482
Mean_4.rename(columns={'Price': 'Price_Silver'}, inplace=True)
Mean_4
# Out:
#       Price_Silver       Open       High        Low  Change %
# Year
# 2000      5.050000   5.088333   5.189167   4.965833 -0.012125
# 2001      4.452500   4.458333   4.610000   4.326667 -0.000650
# 2002      4.629167   4.632500   4.791667   4.469167  0.005900
# 2003      4.975000   4.873333   5.110833   4.730833  0.019183
# 2004      6.795000   6.820833   7.210000   6.294167  0.017758
# 2005      7.519167   7.318333   7.783333   7.104167  0.024358
# 2006     12.106667  11.880000  12.808333  10.971667  0.037717
# 2007     13.846667  13.707500  14.377500  12.995000  0.013675
# 2008     15.142500  15.398333  16.622500  13.734167 -0.015733
# 2009     14.815000  14.376667  15.748333  13.613333  0.039242
# 2010     20.810000  19.664167  21.447500  19.015833  0.053825
# 2011     35.752500  35.721667  39.361667  31.204167  0.005958
# 2012     31.469167  31.305000  33.381667  29.539167  0.010383
# 2013     23.422500  24.475000  25.483333  22.175000 -0.032583
# ...

# %%
Standard_Deviation_Price_Silver = Standard_Deviation_4['Price_Silver']
Standard_Deviation_Price_Silver
# Out:
# Year
# 2000    0.178070
# 2001    0.216506
# 2002    0.223381
# 2003    0.435107
# 2004    0.667458
# 2005    0.641893
# 2006    1.374801
# 2007    0.812497
# 2008    3.469902
# 2009    1.993182
# 2010    4.755408
# 2011    6.000368
# 2012    2.531767
# 2013    4.031815
# 2014    2.048261
# 2015    1.156746
# 2016    1.908709
# 2017    0.650776
# 2018    1.038053
# 2019    1.274955
# 2020    4.644202
# 2021    1.815851
# 2022    2.330542
# 2023    1.291298
# 2024    3.279791
# 2025    0.353553
# Name: Price_Silver, dtype: float64

# %%
Mean_Price_Silver = Mean_4['Price_Silver']
Mean_Price_Silver
# Out:
# Year
# 2000     5.050000
# 2001     4.452500
# 2002     4.629167
# 2003     4.975000
# 2004     6.795000
# 2005     7.519167
# 2006    12.106667
# 2007    13.846667
# 2008    15.142500
# 2009    14.815000
# 2010    20.810000
# 2011    35.752500
# 2012    31.469167
# 2013    23.422500
# 2014    18.665833
# 2015    15.573333
# 2016    17.226667
# 2017    17.370000
# 2018    15.810833
# 2019    16.542500
# 2020    20.970833
# 2021    25.033333
# 2022    21.773333
# 2023    24.231667
# 2024    28.865000
# 2025    33.100000
# Name: Price_Silver, dtype: float64

# %%
df5=pd.read_excel('/content/FTSE 350 - Oil & Gas Producers Historical Data.xlsx')
df5.rename(columns={'ï»¿"Date"': 'Date'}, inplace=True)
df5
df5['Date'] = pd.to_datetime(df5['Date'])

# Extract only the year
df5['Year'] = df5['Date'].dt.year

# Drop the original 'date' column if no longer needed
df5.drop(columns=['Date'], inplace=True)
df5.drop(columns=['Vol.'], inplace=True)

# Display the DataFrame
df5
# Out:
#        Price     Open     High      Low  Change %  Year
# 0    5477.67  5286.39  5525.88  5141.63    0.0362  2025
# 1    5286.39  4906.21  5437.35  4906.21    0.0775  2025
# 2    4906.21  4948.80  5031.01  4695.63   -0.0086  2024
# 3    4948.80  4937.52  5105.48  4798.44    0.0023  2024
# 2009    2186.240833
# 2010    2379.234167
# 2011    2715.385833
# 2012    2708.325833
# 2013    2783.647500
# 2014    2933.400833
# 2015    2488.798333
# 2016    2828.599167
# 2017    3472.947500
# 2018    4167.881667
# 2019    4219.390833
# 2020    2455.789167
# 2021    2825.768333
# 2022    4248.060000
# 2023    4931.602500
# 2024    5208.158333
# 2025    5382.030000
# Name: Price_FTSE350, dtype: float64

# %%
Standard_Deviation_Price_FTSE350 = Standard_Deviation_5['Price_FTSE350']
Standard_Deviation_Price_FTSE350
# Out:
# Year
# 2003     65.430693
# 2004    115.283869
# 2005    166.494871
# 2006     67.961542
# 2007    188.601035
# 2008    188.005113
# 2009    201.977641
# 2010    206.536639
# 2011    129.527458
# 2012    107.150501
# 2013     67.715131
# 2014    182.535107
# 2015    214.280257
# 2016    400.987973
# 2017    265.995149
# 2018    285.081711
# 2019    190.073794
# 2020    529.107205
# 2021    259.508803
# 2022    391.074140
# 2023    259.562490
# 2024    339.982400
# 2025    135.255385
# Name: Price_FTSE350, dtype: float64

# %%
Combined_Standard_Deviation=pd.concat([Standard_Deviation_Price_FTSE100, Standard_Deviation_Price_Gold, Standard_Deviation_Price_Gas, Standard_Deviation_Price_Silver,Standard_Deviation_Price_FTSE350], axis=1)
Combined_Standard_Deviation.dropna(inplace=True)
Combined_Standard_Deviation
# Out:
#       Price_FTSE100  Price_Gold  Price_Gas  Price_Silver  Price_FTSE350
# Year
# 2003     292.292901   24.520546   0.971397      0.435107      65.430693
# 2004     133.580729   20.998028   1.017721      0.667458     115.283869
# 2005     271.250120   31.211258   2.864629      0.641893     166.494871
# 2006     150.203959   30.610083   1.178038      1.374801      67.961542
# 2007     167.774122   64.609820   0.805857      0.812497     188.601035
# 2008     674.407589   66.363929   2.293136      3.469902     188.005113
# 2009     532.580906   83.995128   0.762729      1.993182     201.977641
# 2010     275.954461  110.964432   0.454904      4.755408     206.536639
# 2011     292.383435  145.196357   0.494824      6.000368     129.527458
# 2012     157.587812   60.027692   0.522128      2.531767     107.150501
# 2013     173.437474  151.917011   0.331835      4.031815      67.715131
# 2014     116.706766   55.231734   0.547678      2.048261     182.535107
# ...

# %%
Combined_Mean=pd.concat([Mean_Price_FTSE100, Mean_Price_Gold, Mean_Price_Gas, Mean_Price_Silver,Mean_Price_FTSE350], axis=1)
Combined_Mean.dropna(inplace=True)
Combined_Mean
# Out:
#       Price_FTSE100   Price_Gold  Price_Gas  Price_Silver  Price_FTSE350
# Year
# 2003    4029.835833   368.008333   5.508250      4.975000    1194.467500
# 2004    4519.822500   411.408333   6.306667      6.795000    1403.321667
# 2005    5167.510833   448.641667   9.162000      7.519167    1804.265833
# 2006    5940.907500   613.908333   7.069917     12.106667    2040.985000
# 2007    6425.190000   705.483333   7.242667     13.846667    2111.785000
# 2008    5356.945833   876.775000   8.904583     15.142500    2196.074167
# 2009    4593.000000   984.783333   4.197500     14.815000    2186.240833
# 2010    5418.041667  1237.783333   4.327000     20.810000    2379.234167
# 2011    5727.619167  1574.075000   4.076833     35.752500    2715.385833
# 2012    5715.626667  1676.325000   2.892333     31.469167    2708.325833
# 2013    6492.117500  1394.400000   3.757750     23.422500    2783.647500
# 2014    6691.229167  1251.308333   4.218167     18.665833    2933.400833
# ...

# %%
Combined_Mean['Price_Gas'].plot(kind='line',color='green')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.title('Mean of Natural Gas')
# Out:
# Text(0.5, 1.0, 'Mean of Natural Gas')

# %%
Combined_Mean['Price_Gold'].plot(kind='line',color='gold')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.title('Mean of Gold')
# Out:
# Text(0.5, 1.0, 'Mean of Gold')

# %%
Combined_Mean['Price_Silver'].plot(kind='line',color='silver')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.title('Mean of Silver')
# Out:
# Text(0.5, 1.0, 'Mean of Silver')

# %%
Combined_Mean['Price_FTSE100'].plot(kind='line',color='purple')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.title('Mean of FTSE 100')
# Out:
# Text(0.5, 1.0, 'Mean of FTSE 100')

# %%
plt.figure(figsize=(50,50))
Combined_Mean.plot(kind='line')
plt.xlabel('Year')
plt.ylabel('Mean')
plt.title('Mean')
# Out:
# Text(0.5, 1.0, 'Mean')

# %%
plt.figure(figsize=(50,50))
Combined_Standard_Deviation.plot(kind='line')
plt.xlabel('Year')
plt.ylabel('Standard Deviation')
plt.title('Standard deviation')
# Out:
# Text(0.5, 1.0, 'Standard deviation')

# %%
Combined_Standard_Deviation['Price_Gas'].plot(kind='line',color='green')
plt.xlabel('Year')
plt.ylabel('Standard Deviation')
plt.title('Standard deviation of Natural Gas')
# Out:
# Text(0.5, 1.0, 'Standard deviation of Natural Gas')

# %%
Combined_Standard_Deviation['Price_Silver'].plot(kind='line',color='silver')
plt.xlabel('Year')
plt.ylabel('Standard Deviation')
plt.title('Standard deviation of Silver')
# Out:
# Text(0.5, 1.0, 'Standard deviation of Silver')

# %%
Combined_Standard_Deviation['Price_FTSE350'].plot(kind='line',color='Blue')
plt.xlabel('Year')
plt.ylabel('Standard Deviation')
plt.title('Standard deviation of FTSE 350')
# Out:
# Text(0.5, 1.0, 'Standard deviation of FTSE 350')

# %%
Combined_Standard_Deviation['Price_Gold'].plot(kind='line',color='gold')
plt.xlabel('Year')
plt.ylabel('Standard Deviation')
plt.title('Standard deviation of Gold')
# Out:
# Text(0.5, 1.0, 'Standard deviation of Gold')

# %%
Combined_Standard_Deviation['Price_FTSE100'].plot(kind='line',color='purple')
plt.xlabel('Year')
plt.ylabel('Standard Deviation')
plt.title('Standard deviation of FTSE 100')
# Out:
# Text(0.5, 1.0, 'Standard deviation of FTSE 100')

# %%
returns_df=Combined_Mean.pct_change().dropna()
returns_df
# Out:
#       Price_FTSE100  Price_Gold  Price_Gas  Price_Silver  Price_FTSE350
# Year
# 2004       0.121590    0.117932   0.144949      0.365829       0.174851
# 2005       0.143300    0.090502   0.452748      0.106573       0.285711
# 2006       0.149665    0.368371  -0.228344      0.610108       0.131200
# 2007       0.081517    0.149167   0.024435      0.143722       0.034689
# 2008      -0.166259    0.242800   0.229462      0.093584       0.039914
# 2009      -0.142608    0.123188  -0.528614     -0.021628      -0.004478
# 2010       0.179630    0.256909   0.030852      0.404657       0.088276
# 2011       0.057138    0.271689  -0.057815      0.718044       0.141286
# 2012      -0.002094    0.064959  -0.290544     -0.119805      -0.002600
# 2013       0.135854   -0.168180   0.299211     -0.255700       0.027811
# 2014       0.030670   -0.102619   0.122525     -0.203081       0.053798
# 2015      -0.017365   -0.079157  -0.385357     -0.165677      -0.151566
# ...

# %%
correlation_matrix=returns_df.corr()
correlation_matrix
# Out:
#                Price_FTSE100  Price_Gold  Price_Gas  Price_Silver  \
# Price_FTSE100       1.000000   -0.102722   0.395442      0.246364
# Price_Gold         -0.102722    1.000000  -0.221316      0.832550
# Price_Gas           0.395442   -0.221316   1.000000     -0.078837
# Price_Silver        0.246364    0.832550  -0.078837      1.000000
# Price_FTSE350       0.533785   -0.178012   0.478741     -0.004498
#
#                Price_FTSE350
# Price_FTSE100       0.533785
# Price_Gold         -0.178012
# Price_Gas           0.478741
# Price_Silver       -0.004498
# Price_FTSE350       1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
Bank_Year1=df.groupby('Year')
Bank_Year=Bank_Year1.mean()
Bank_Year
# Out:
#           Rate
# Year
# 2003  3.666667
# 2004     4.375
# 2005       4.5
# 2006     4.875
# 2007       5.5
# 2008      3.95
# 2009       1.0
# 2016      0.25
# 2017       0.5
# 2018      0.75
# 2020     0.175
# 2021      0.25
# 2022      1.75
# 2023       4.6
# 2024     4.875
# 2025       4.5

# %%
series=pd.read_excel('/content/GDP 1.xlsx')
series.drop(range(0,61),inplace=True)
series.rename(columns={'Unnamed: 0': 'Year'}, inplace=True)
series.rename(columns={'Unnamed: 1': 'GDP %'}, inplace=True)
series.reset_index(drop=True, inplace=True)
series.set_index('Year', inplace=True)
GDP_london=series
GDP_london
# Out:
#      GDP %
# Year
# 2003   3.2
# 2004   2.5
# 2005   2.7
# 2006   2.4
# 2007   2.6
# 2008  -0.2
# 2009  -4.6
# 2010   2.2
# 2011   1.1
# 2012   1.5
# 2013   1.8
# 2014   3.2
# 2015   2.2
# 2016   1.9
# 2017   2.7
# 2018   1.4
# 2019   1.6
# 2020 -10.3
# 2021   8.6
# 2022   4.8
# 2023   0.4
# 2024   0.9

# %%
Correlation_2=pd.concat([Bank_Year,series,Mean_Price_FTSE100,Mean_Price_FTSE350],axis=1)
Correlation_3=Correlation_2.pct_change().dropna()
correlation_matrix_2=Correlation_3.corr()
correlation_matrix_2
# Out:
# <ipython-input-233-19782e39b0a5>:2: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   Correlation_3=Correlation_2.pct_change().dropna()
# <ipython-input-233-19782e39b0a5>:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Correlation_3=Correlation_2.pct_change().dropna()
#                    Rate     GDP %  Price_FTSE100  Price_FTSE350
# Rate           1.000000 -0.111750       0.091081       0.419262
# GDP %         -0.111750  1.000000      -0.166760       0.013079
# Price_FTSE100  0.091081 -0.166760       1.000000       0.655538
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_2, annot=True, cmap='Purples', fmt=".2f")
plt.title('Correlation Matrix 2')
plt.show()

# %%
Bank_rate_usa=pd.read_excel('/content/Book1.xlsx')
Bank_rate_usa.drop(['Unnamed: 1','Unnamed: 2'],axis=1,inplace=True)
Bank_rate_usa.drop([0,1,23,24],inplace=True)
Bank_rate_usa.reset_index
Bank_rate_usa
# Out:
#    Unnamed: 0 Unnamed: 3
# 2        2023     0.0289
# 3        2022     0.0251
# 4        2021     0.0606
# 5        2020    -0.0216
# 6        2019     0.0258
# 7        2018     0.0297
# 8        2017     0.0246
# 9        2016     0.0182
# 10       2015     0.0295
# 11       2014     0.0252
# 12       2013     0.0212
# 13       2012     0.0229
# 14       2011     0.0156
# 15       2010      0.027
# 16       2009    -0.0258
# 17       2008     0.0011
# 18       2007       0.02
# 19       2006     0.0278
# 20       2005     0.0348
# 21       2004     0.0385
# 22       2003      0.028

# %%
Bank_rate_usa.rename(columns={'Unnamed: 0':'Year'},inplace=True)
Bank_rate_usa.rename(columns={'Unnamed: 3':'GDP'},inplace=True)
Bank_rate_usa.sort_values(by='Year',ascending=True,inplace=True)
Bank_rate_usa.reset_index(drop=True, inplace=True)
Bank_rate_usa
# Out:
#     Year     GDP
# 0   2003   0.028
# 1   2004  0.0385
# 2   2005  0.0348
# 3   2006  0.0278
# 4   2007    0.02
# 5   2008  0.0011
# 6   2009 -0.0258
# 7   2010   0.027
# 8   2011  0.0156
# 9   2012  0.0229
# 10  2013  0.0212
# 11  2014  0.0252
# 12  2015  0.0295
# 13  2016  0.0182
# 14  2017  0.0246
# 15  2018  0.0297
# 16  2019  0.0258
# 17  2020 -0.0216
# 18  2021  0.0606
# 19  2022  0.0251
# 20  2023  0.0289

# %%
Bank_rate_usa['GDP']=Bank_rate_usa['GDP']/100
Bank_rate_usa
# Out:
#     Year   GDP
# 0   2003   2.8
# 1   2004  3.85
# 2   2005  3.48
# 3   2006  2.78
# 4   2007   2.0
# 5   2008  0.11
# 6   2009 -2.58
# 7   2010   2.7
# 8   2011  1.56
# 9   2012  2.29
# 10  2013  2.12
# 11  2014  2.52
# 12  2015  2.95
# 13  2016  1.82
# 14  2017  2.46
# 15  2018  2.97
# 16  2019  2.58
# 17  2020 -2.16
# 18  2021  6.06
# 19  2022  2.51
# 20  2023  2.89

# %%
GDP_Usa=Bank_rate_usa
GDP_Usa=GDP_Usa.set_index('Year')
GDP_Usa
# Out:
#        GDP
# Year
# 2003   2.8
# 2004  3.85
# 2005  3.48
# 2006  2.78
# 2007   2.0
# 2008  0.11
# 2009 -2.58
# 2010   2.7
# 2011  1.56
# 2012  2.29
# 2013  2.12
# 2014  2.52
# 2015  2.95
# 2016  1.82
# 2017  2.46
# 2018  2.97
# 2019  2.58
# 2020 -2.16
# 2021  6.06
# 2022  2.51
# 2023  2.89

# %%
Fed_rate_US = pd.read_excel('/content/Book2.xlsx')
Fed_rate_US.rename(columns={'us fed rate':'Fed Rate'},inplace=True)
Fed_rate_US.drop([0,1],inplace=True)
# Out:
#       Year  Fed Rate
# 2   2024.0    0.0515
# 3   2023.0    0.0503
# 4   2022.0    0.0168
# 5   2021.0    0.0008
# 6   2020.0    0.0036
# 7   2019.0    0.0216
# 8   2018.0    0.0179
# 9   2017.0    0.0100
# 10  2016.0    0.0039
# 11  2015.0    0.0013
# 12  2014.0    0.0009
# 13  2013.0    0.0011
# 14  2012.0    0.0014
# 15  2011.0    0.0010
# 16  2010.0    0.0018
# 17  2009.0    0.0016
# 18  2008.0    0.0192
# 19  2007.0    0.0502
# 20  2006.0    0.0497
# 21  2005.0    0.0322
# 22  2004.0    0.0135
# 23  2003.0    0.0113

# %%
Fed_rate_US.sort_values(by='Year',ascending=True,inplace=True)
Fed_rate_US.reset_index(drop=True,inplace=True)
# Out:
#       Year  Fed Rate
# 0   2003.0    0.0113
# 1   2004.0    0.0135
# 2   2005.0    0.0322
# 3   2006.0    0.0497
# 4   2007.0    0.0502
# 5   2008.0    0.0192
# 6   2009.0    0.0016
# 7   2010.0    0.0018
# 8   2011.0    0.0010
# 9   2012.0    0.0014
# 10  2013.0    0.0011
# 11  2014.0    0.0009
# 12  2015.0    0.0013
# 13  2016.0    0.0039
# 14  2017.0    0.0100
# 15  2018.0    0.0179
# 16  2019.0    0.0216
# 17  2020.0    0.0036
# 18  2021.0    0.0008
# 19  2022.0    0.0168
# 20  2023.0    0.0503
# 21  2024.0    0.0515

# %%
Fed_rate_US['Fed Rate']=Fed_rate_US['Fed Rate']*100
# Out:
#       Year  Fed Rate
# 0   2003.0      1.13
# 1   2004.0      1.35
# 2   2005.0      3.22
# 3   2006.0      4.97
# 4   2007.0      5.02
# 5   2008.0      1.92
# 6   2009.0      0.16
# 7   2010.0      0.18
# 8   2011.0      0.10
# 9   2012.0      0.14
# 10  2013.0      0.11
# 11  2014.0      0.09
# 12  2015.0      0.13
# 13  2016.0      0.39
# 14  2017.0      1.00
# 15  2018.0      1.79
# 16  2019.0      2.16
# 17  2020.0      0.36
# 18  2021.0      0.08
# 19  2022.0      1.68
# 20  2023.0      5.03
# 21  2024.0      5.15

# %%
Fed_rate_US['Year']=Fed_rate_US['Year'].astype(int)
Fed_rate_US
# Out:
#     Year  Fed Rate
# 0   2003      1.13
# 1   2004      1.35
# 2   2005      3.22
# 3   2006      4.97
# 4   2007      5.02
# 5   2008      1.92
# 6   2009      0.16
# 7   2010      0.18
# 8   2011      0.10
# 9   2012      0.14
# 10  2013      0.11
# 11  2014      0.09
# 12  2015      0.13
# 13  2016      0.39
# 14  2017      1.00
# 15  2018      1.79
# 16  2019      2.16
# 17  2020      0.36
# 18  2021      0.08
# 19  2022      1.68
# 20  2023      5.03
# 21  2024      5.15

# %%
Fed_rate_US=Fed_rate_US.set_index('Year')
Fed_rate_US
# Out:
#       Fed Rate
# Year
# 2003      1.13
# 2004      1.35
# 2005      3.22
# 2006      4.97
# 2007      5.02
# 2008      1.92
# 2009      0.16
# 2010      0.18
# 2011      0.10
# 2012      0.14
# 2013      0.11
# 2014      0.09
# 2015      0.13
# 2016      0.39
# 2017      1.00
# 2018      1.79
# 2019      2.16
# 2020      0.36
# 2021      0.08
# 2022      1.68
# 2023      5.03
# 2024      5.15

# %%
Correlation_4= pd.concat([Fed_rate_US,GDP_Usa,Mean_Price_Gas,Mean_Price_Gold,Mean_Price_Silver],axis=1)
Correlation_4
# Out:
#       Fed Rate   GDP  Price_Gas   Price_Gold  Price_Silver
# Year
# 2003      1.13   2.8   5.508250   368.008333      4.975000
# 2004      1.35  3.85   6.306667   411.408333      6.795000
# 2005      3.22  3.48   9.162000   448.641667      7.519167
# 2006      4.97  2.78   7.069917   613.908333     12.106667
# 2007      5.02   2.0   7.242667   705.483333     13.846667
# 2008      1.92  0.11   8.904583   876.775000     15.142500
# 2009      0.16 -2.58   4.197500   984.783333     14.815000
# 2010      0.18   2.7   4.327000  1237.783333     20.810000
# 2011      0.10  1.56   4.076833  1574.075000     35.752500
# 2012      0.14  2.29   2.892333  1676.325000     31.469167
# 2013      0.11  2.12   3.757750  1394.400000     23.422500
# 2014      0.09  2.52   4.218167  1251.308333     18.665833
# 2015      0.13  2.95   2.592667  1152.258333     15.573333
# 2016      0.39  1.82   2.677417  1247.366667     17.226667
# 2017      1.00  2.46   3.014833  1266.508333     17.370000
# ...

# %%
Correlation_4=Correlation_4.pct_change().dropna()
Correlation_matrix_3=Correlation_4.corr()
Correlation_matrix_3
# Out:
# <ipython-input-282-40f72bf4d443>:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   Correlation_4=Correlation_4.pct_change().dropna()
# <ipython-input-282-40f72bf4d443>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Correlation_4=Correlation_4.pct_change().dropna()
#               Fed Rate       GDP  Price_Gas  Price_Gold  Price_Silver
# Fed Rate      1.000000  0.105896   0.353761   -0.060398     -0.084125
# GDP           0.105896  1.000000   0.257887    0.042571      0.055162
# Price_Gas     0.353761  0.257887   1.000000   -0.108328     -0.113438
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(Correlation_matrix_3, annot=True, cmap='Blues', fmt=".2f")
plt.title('Correlation Matrix USA')
plt.show()

# %%
Independent=pd.concat([Fed_rate_US,GDP_Usa],axis=1)

Independent.drop(2024,inplace=True)
Independent
# Out:
#       Fed Rate   GDP
# Year
# 2003      1.13   2.8
# 2004      1.35  3.85
# 2005      3.22  3.48
# 2006      4.97  2.78
# 2007      5.02   2.0
# 2008      1.92  0.11
# 2009      0.16 -2.58
# 2010      0.18   2.7
# 2011      0.10  1.56
# 2012      0.14  2.29
# 2013      0.11  2.12
# 2014      0.09  2.52
# 2015      0.13  2.95
# 2016      0.39  1.82
# 2017      1.00  2.46
# 2018      1.79  2.97
# 2019      2.16  2.58
# 2020      0.36 -2.16
# 2021      0.08  6.06
# 2022      1.68  2.51
# 2023      5.03  2.89

# %%
Common_df=pd.concat([returns_df,Independent],axis=1)
Common_df.drop([2003,2025,2024],inplace=True)
Common_df['GDP']=Common_df['GDP'].astype(float)
Common_df
# Out:
#       Price_FTSE100  Price_Gold  Price_Gas  Price_Silver  Price_FTSE350  \
# Year
# 2004       0.121590    0.117932   0.144949      0.365829       0.174851
# 2005       0.143300    0.090502   0.452748      0.106573       0.285711
# 2006       0.149665    0.368371  -0.228344      0.610108       0.131200
# 2007       0.081517    0.149167   0.024435      0.143722       0.034689
# 2008      -0.166259    0.242800   0.229462      0.093584       0.039914
# 2009      -0.142608    0.123188  -0.528614     -0.021628      -0.004478
# 2010       0.179630    0.256909   0.030852      0.404657       0.088276
# 2011       0.057138    0.271689  -0.057815      0.718044       0.141286
# 2012      -0.002094    0.064959  -0.290544     -0.119805      -0.002600
# 2013       0.135854   -0.168180   0.299211     -0.255700       0.027811
# 2014       0.030670   -0.102619   0.122525     -0.203081       0.053798
# 2015      -0.017365   -0.079157  -0.385357     -0.165677      -0.151566
# ...

# %%
import statsmodels.api as sm

# %%
X= Common_df[['Fed Rate','GDP']]
Y =Common_df['Price_Gold']
X=sm.add_constant(X)
model = sm.OLS(Y,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Price_Gold   R-squared:                       0.269
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     3.124
# Date:                Sat, 22 Feb 2025   Prob (F-statistic):             0.0699
# Time:                        18:51:02   Log-Likelihood:                 14.945
# No. Observations:                  20   AIC:                            -23.89
# Df Residuals:                      17   BIC:                            -20.90
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1107      0.047      2.369      0.030       0.012       0.209
# ...

# %%
common_df_london=pd.concat([Bank_Year,GDP_london,returns_df],axis=1)
common_df_london
# Out:
#           Rate GDP %  Price_FTSE100  Price_Gold  Price_Gas  Price_Silver  \
# Year
# 2003  3.666667   3.2            NaN         NaN        NaN           NaN
# 2004     4.375   2.5       0.121590    0.117932   0.144949      0.365829
# 2005       4.5   2.7       0.143300    0.090502   0.452748      0.106573
# 2006     4.875   2.4       0.149665    0.368371  -0.228344      0.610108
# 2007       5.5   2.6       0.081517    0.149167   0.024435      0.143722
# 2008      3.95  -0.2      -0.166259    0.242800   0.229462      0.093584
# 2009       1.0  -4.6      -0.142608    0.123188  -0.528614     -0.021628
# 2016      0.25   1.9      -0.003569    0.082541   0.032688      0.106164
# 2017       0.5   2.7       0.124475    0.015346   0.126023      0.008320
# 2018      0.75   1.4      -0.002609   -0.001770   0.010365     -0.089762
# 2020     0.175 -10.3      -0.159127    0.266018  -0.105863      0.267694
# 2021      0.25   8.6       0.133440    0.008832   0.716430      0.193721
# ...

# %%
common_df_london=pd.concat([Bank_Year,GDP_london,returns_df],axis=1)


# Convert columns to numeric, coercing errors to NaN
common_df_london['Rate'] = pd.to_numeric(common_df_london['Rate'], errors='coerce')
common_df_london['GDP %'] = pd.to_numeric(common_df_london['GDP %'], errors='coerce')
common_df_london['Price_FTSE100'] = pd.to_numeric(common_df_london['Price_FTSE100'], errors='coerce')

# Drop rows with any NaN values
common_df_london.dropna(inplace=True)

X= common_df_london[['Rate','GDP %']]
Y =common_df_london['Price_FTSE100']
X=sm.add_constant(X)
model = sm.OLS(Y,X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          Price_FTSE100   R-squared:                       0.635
# Model:                            OLS   Adj. R-squared:                  0.569
# Method:                 Least Squares   F-statistic:                     9.577
# Date:                Sat, 22 Feb 2025   Prob (F-statistic):            0.00390
# Time:                        19:01:27   Log-Likelihood:                 18.231
# No. Observations:                  14   AIC:                            -30.46
# Df Residuals:                      11   BIC:                            -28.54
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0199      0.033     -0.612      0.553      -0.091       0.052
# ...
